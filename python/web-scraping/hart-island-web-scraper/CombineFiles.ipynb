# %% [markdown]
# # Combine Files
# ----
#
# The purpose of this notebook is to combine multiple scraped files into one.

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/simonaytes/Documents/GitHub/hart-island-web-scraper/data/output/DOC_2022-09-04_17:27:43.csv")
df2 = pd.read_csv("/Users/simonaytes/Documents/GitHub/hart-island-web-scraper/data/output/DOC_2022-09-04_17:27:38.csv")
df3 = pd.read_csv("/Users/simonaytes/Documents/GitHub/hart-island-web-scraper/data/output/DOC_2022-09-04_17:27:34.csv")
df4 = pd.read_csv("/Users/simonaytes/Documents/GitHub/hart-island-web-scraper/data/output/DOC_2022-09-04_17:27:28.csv")
df5 = pd.read_csv("/Users/simonaytes/Documents/GitHub/hart-island-web-scraper/data/output/DOC_2022-09-04_14:07:38.csv")
df6 = pd.read_csv("/Users/simonaytes/Documents/GitHub/hart-island-web-scraper/data/output/DOC_2022-09-02_14:55:56.csv")
df7 = pd.read_csv("/Users/simonaytes/Documents/GitHub/hart-island-web-scraper/data/output/hart-island.csv")

# %%
hart_island['DOD'] = pd.to_datetime(hart_island['DOD'])
hart_island['DateScraped'] = pd.to_datetime(hart_island['DateScraped'])

# %%
hart_island = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
hart_island = hart_island.sort_values(by='DOD')

# %%
hart_island
# Out:
#          FName      LName   Age      Sex        DOD  \
# 987      ALGIE   GIDDINGS  59.0  UNKNOWN 1977-01-15
# 986     GLADYS  FUMBINNER  84.0   FEMALE 1977-01-18
# 985  ELIZABETH   EUBOULES  61.0   FEMALE 1977-01-19
# 984       PAUL        FOX  71.0     MALE 1977-01-24
# 983    CHARLES     TRAVIS  80.0     MALE 1977-01-25
# ..         ...        ...   ...      ...        ...
# 1       WILLIE       KING  73.0     MALE 2019-12-31
# 4        JOYCE      MCCOY  73.0   FEMALE 2019-12-31
# 3        LAURA   MCCADDEN  49.0   FEMALE 2019-12-31
# 2      WILLIAM      BROWN  56.0     MALE 2019-12-31
# 0       RONALD       ROSS  63.0     MALE 2019-12-31
#
#                                                    POD  PlotNo      CaseNo  \
# 987                     NEW YORK PRESBYTERIAN HOSPITAL   110.0         NaN
# 986                                 110 VALENTINE LANE   127.0         NaN
# 985                             HARLEM HOSPITAL CENTER   103.0         NaN
# ...

# %%
hart_island.to_csv("./data/output/hart-island-full.csv", index=False)

# %%
hart_island
# Out:
#          FName      LName   Age      Sex        DOD  \
# 987      ALGIE   GIDDINGS  59.0  UNKNOWN 1977-01-15
# 986     GLADYS  FUMBINNER  84.0   FEMALE 1977-01-18
# 985  ELIZABETH   EUBOULES  61.0   FEMALE 1977-01-19
# 984       PAUL        FOX  71.0     MALE 1977-01-24
# 983    CHARLES     TRAVIS  80.0     MALE 1977-01-25
# ..         ...        ...   ...      ...        ...
# 1       WILLIE       KING  73.0     MALE 2019-12-31
# 4        JOYCE      MCCOY  73.0   FEMALE 2019-12-31
# 3        LAURA   MCCADDEN  49.0   FEMALE 2019-12-31
# 2      WILLIAM      BROWN  56.0     MALE 2019-12-31
# 0       RONALD       ROSS  63.0     MALE 2019-12-31
#
#                                                    POD  PlotNo      CaseNo  \
# 987                     NEW YORK PRESBYTERIAN HOSPITAL   110.0         NaN
# 986                                 110 VALENTINE LANE   127.0         NaN
# 985                             HARLEM HOSPITAL CENTER   103.0         NaN
# ...
